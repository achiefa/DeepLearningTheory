# %%
from validphys.api import API
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib import colors as mcolors
from matplotlib.colors import LogNorm
import sys
from collections import namedtuple

# Add the path to the library folder
sys.path.append('./lib')

from model import PDFmodel
from validphys.api import API

from mpl_toolkits.axes_grid1 import make_axes_locatable

import numpy as np
import pandas as pd

# %%
seed = 14132124

# %%
evol_basis = np.array([
  'gamma',
  'Sigma',
  'g',
  'V',
  'V3',
  'V8',
  'V15',
  'V24',
  'V35',
  'T3',
  'T8',
  'T15',
  'T24',
  'T35'
])

evol_basis_tex = np.array([
  r'$\gamma$',
  r'$\Sigma$',
  r'$g$',
  r'$V$',
  r'$V_3$',
  r'$V_8$',
  r'$V_{15}$',
  r'$V_{24}$',
  r'$V_{35}$',
  r'$T_3$',
  r'$T_8$',
  r'$T_{15}$',
  r'$T_{24}$',
  r'$T_{35}$'
])

# %%
def generate_dicts(common_dict):
  """Collect the necessary data from `validphys` given a validphys-like
  dictionary.

  Returns
  -------
  Returns a named tuple with the following fields:
  - fk_tables: dict
    Dictionary of FK tables.
  - central_data: dict
    Dictionary of central data.
  - xgrid: np.array
    The largest grids amongst all datasets.
  - total_ndata_wc: int
    Total number of data points.
  - lumi_mapping: np.array
    Luminosity mapping.
  """
  groups_data = API.procs_data(**common_dict)

  # Initialize named tuple
  result_tuple = namedtuple('result_tuple', ('fk_tables', 'central_data', 'xgrid', 'total_ndata_wc', 'lumi_mapping'))

  # Initialise the dictionaries
  fk_table_dict = {}
  central_data_dict = {}
  lumi_mapping = np.array([])
  flag = True

  XGRID = np.array([])


  total_ndata_wc = 0
  for group_proc in groups_data:
    for exp_set in group_proc.datasets:
      dataset_name = exp_set.name
      dataset_size = exp_set.load_commondata().ndata
      total_ndata_wc += dataset_size
      cuts = exp_set.cuts
      central_data_dict[dataset_name] = exp_set.load_commondata().with_cuts(cuts).central_values.to_numpy()

      # Collect FKSpecs
      fk_data = exp_set.fkspecs[0].load_with_cuts(cuts)

      # Read FKData and FK table in numpy version
      fk_table = fk_data.get_np_fktable()
      fk_table_dict[dataset_name] = fk_table

      # Collect lumi mapping
      if flag:
        lumi_mapping = np.array(fk_data.luminosity_mapping)
        flag = False
      if not np.allclose(lumi_mapping, np.array(fk_data.luminosity_mapping)):
        raise ValueError('Lumi mapping is not the same for all datasets.')

      # xgrid for this dataset
      xgrid = fk_data.xgrid
      if xgrid.size > XGRID.size:
        XGRID = xgrid

      # Check that `large_xgrid` is just a small-x extension of xgrid
      for i, x in enumerate(xgrid):
        offset = XGRID.size - xgrid.size
        try:
          assert(np.isclose(x, XGRID[offset+i]))
        except AssertionError:
          print(f"`large_xgrid` is not an extension for {dataset_name}.")

  res = result_tuple(fk_tables=fk_table_dict, central_data=central_data_dict, xgrid=XGRID, total_ndata_wc=total_ndata_wc, lumi_mapping=lumi_mapping)
  return res


def pad_fk_tables(fk_table_dict, grid_size):
  res_dict = {}
  for dataset_name, fk_table in fk_table_dict.items():
    res_dict[dataset_name] = np.pad(fk_table, ((0, 0), (0,0), (grid_size - fk_table.shape[2], 0)), 'constant')
  return res_dict


def build_fk_matrix(fk_dict):
   """
   Construct the FK table matrix.

   Description
   -----------
   Each experiment is provided with an FK table. By construction, and
   for the present work, FK tables are padded with zeros such that
   the number of points in the x-grid is the same (i.e. 50). Thus,
   each FK table has shape (Ndat, 50, 9). First, the last two dimensions
   (which are equal for all FK tables) are flattened, thus leaving 
   the shape (Ndat, 450). Then, all FK tables are stacked together,
   yielding a matrix (tot_Ndat, 450), where `tot_Ndata` is the sum
   off all experimental point. In this way, each row of this matrix
   represents an experimental point and contains the information to
   compute its relative theoretical prediction.

   Parameters
   ----------
   fk_dict: dict
    Dictionary of FK tables.
   """
   ndata = 0
   for fk in fk_dict.values():
      ndata += fk.shape[0]

   FK = np.vstack([fk.reshape((fk.shape[0], fk.shape[1] * fk.shape[2])) for fk in fk_dict.values()])

   # Check that this FK is what we expect
   try:
     test_matrix = np.random.rand(FK.shape[0], FK.shape[0]) # Random matrix
     mat_prod = FK.T @ test_matrix  # Matrix product
 
     # Tensor product
     result = np.zeros((fk.shape[1], fk.shape[2], FK.shape[0]))
     I = 0
     for fk in fk_dict.values():
       ndata = fk.shape[0]
       result += np.einsum('Iia, IJ -> iaJ',fk, test_matrix[I : I + ndata, :])
       I += ndata
     
     result_flatten = result.reshape((result.shape[0] * result.shape[1], result.shape[2]))
     assert(np.allclose(result_flatten, mat_prod))
     assert(np.allclose(result, mat_prod.reshape((result.shape[0], result.shape[1], result.shape[2]))))
   except AssertionError:
     print('The FK matrix does not match with the FK dict.')
   else:
      return FK
   

def plot_matrix(matrix, x_labels, x_ticklocks, size=(20,20), fontsize=10, y_labels=None, y_ticklocks=None):
  # Show the FK tables
  fig, ax = plt.subplots(figsize=size)
  matrixplot = ax.matshow(
      matrix,
      cmap=cm.Spectral_r,
      norm=mcolors.SymLogNorm(
          linthresh=0.00001, linscale=1, vmin=matrix.min(), vmax=matrix.max()
      ),
  )
  divider = make_axes_locatable(ax)
  cax = divider.append_axes("right", size="5%", pad=0.5)
  cbar = fig.colorbar(matrixplot, cax=cax)
  cbar.ax.tick_params(labelsize=fontsize)

  ax.set_xticks(x_ticklocks)
  _ = ax.set_xticklabels(x_labels, rotation=20, ha="left", fontsize=fontsize)

  if y_labels is not None and y_ticklocks is not None:
    ax.set_xticks(x_ticklocks)
    _ = ax.set_xticklabels(x_labels, rotation=20, ha="left", fontsize=fontsize)

# %%
# List of DIS dataset
dataset_inputs = [
  #{'dataset': 'NMC_NC_NOTFIXED_P_EM-SIGMARED', 'frac': 0.75, 'variant': 'legacy'},
  {'dataset': 'SLAC_NC_NOTFIXED_P_EM-F2', 'frac': 0.75, 'variant': 'legacy'},
  {'dataset': 'SLAC_NC_NOTFIXED_D_EM-F2', 'frac': 0.75, 'variant': 'legacy'},
  {'dataset': 'BCDMS_NC_NOTFIXED_P_EM-F2', 'frac': 0.75, 'variant': 'legacy'},
  {'dataset': 'BCDMS_NC_NOTFIXED_D_EM-F2', 'frac': 0.75, 'variant': 'legacy'},
  {'dataset': 'CHORUS_CC_NOTFIXED_PB_NU-SIGMARED', 'frac': 0.75, 'variant': 'legacy'},
  {'dataset': 'CHORUS_CC_NOTFIXED_PB_NB-SIGMARED', 'frac': 0.75, 'variant': 'legacy'},
  {'dataset': 'NUTEV_CC_NOTFIXED_FE_NU-SIGMARED', 'cfac': ['MAS'], 'frac': 0.75, 'variant': 'legacy'},
  {'dataset': 'NUTEV_CC_NOTFIXED_FE_NB-SIGMARED', 'cfac': ['MAS'], 'frac': 0.75, 'variant': 'legacy'},
  {'dataset': 'HERA_NC_318GEV_EM-SIGMARED', 'frac': 0.75, 'variant': 'legacy'},
  {'dataset': 'HERA_NC_225GEV_EP-SIGMARED', 'frac': 0.75, 'variant': 'legacy'},
  {'dataset': 'HERA_NC_251GEV_EP-SIGMARED', 'frac': 0.75, 'variant': 'legacy'},
  {'dataset': 'HERA_NC_300GEV_EP-SIGMARED', 'frac': 0.75, 'variant': 'legacy'},
  {'dataset': 'HERA_NC_318GEV_EP-SIGMARED', 'frac': 0.75, 'variant': 'legacy'},
  {'dataset': 'HERA_CC_318GEV_EM-SIGMARED', 'frac': 0.75, 'variant': 'legacy'},
  {'dataset': 'HERA_CC_318GEV_EP-SIGMARED', 'frac': 0.75, 'variant': 'legacy'},
  {'dataset': 'HERA_NC_318GEV_EAVG_CHARM-SIGMARED', 'frac': 0.75, 'variant': 'legacy'},
  {'dataset': 'HERA_NC_318GEV_EAVG_BOTTOM-SIGMARED', 'frac': 0.75, 'variant': 'legacy'},
]

# Dictionary for validphys API
common_dict = dict(
    dataset_inputs=dataset_inputs,
    metadata_group="nnpdf31_process",
    use_cuts='internal',
    datacuts={'q2min': 3.49, 'w2min': 12.5},
    theoryid=708,
    t0pdfset='NNPDF40_nnlo_as_01180',
    use_t0=True
)

# %%
# Retrieve data from NNPDF
tuple_of_dicts = generate_dicts(common_dict)
fk_table_dict = tuple_of_dicts.fk_tables
central_data_dict = tuple_of_dicts.central_data
lumi_mapping = tuple_of_dicts.lumi_mapping
XGRID = tuple_of_dicts.xgrid

fk_table_dict_padded = pad_fk_tables(fk_table_dict, XGRID.size)
FK = build_fk_matrix(fk_table_dict_padded)

# %%
plot_matrix(FK, x_labels=evol_basis_tex[lumi_mapping] , x_ticklocks=np.arange(0, FK.shape[1], XGRID.size))

# %%
C = API.groups_covmat_no_table(**common_dict)
Cinv = pd.DataFrame(np.linalg.inv(C), index=C.index, columns=C.columns)

# Diagonalize covariance matrix
eigvals_Cinv, R_Y = np.linalg.eigh(Cinv)
if eigvals_Cinv[-1] > eigvals_Cinv[0]:
    eigvals_Cinv = eigvals_Cinv[::-1]
    R_Y = R_Y[:,::-1]
D_Y = np.diag(eigvals_Cinv)

# %%
# Construct dataframe for predictions
Y = pd.DataFrame(np.zeros(Cinv.shape[0]), index=Cinv.index)
for exp_name, data in central_data_dict.items():
  if data.size == Y.loc[(slice(None), [exp_name], slice(None)), :].size:
    # (group, experiment, index)
    Y.loc[(slice(None), [exp_name], slice(None)), :] = data
  else:
    raise ValueError

# %%
nnpdf_model = PDFmodel(input=XGRID,
                       outputs=9,
                       architecture=[28,20],
                       activations=['tanh', 'tanh'],
                       kernel_initializer='RandomNormal',
                       user_ki_args={'mean': 0.0, 'stddev': 1.0},
                       seed=seed,
                       dtype='float64')
NTK = nnpdf_model.compute_ntk()

# Flatten NTK
prod = 1
oldshape = NTK.shape
for k in oldshape[2:]:
    prod *= k
NTK_flat = np.array(NTK).reshape(prod,-1)

# Compute predictions at initialization
f0 = nnpdf_model.predict(squeeze=True)

# %% [markdown]
# # Computing matrices from notes
# -------------------------------

# %%
def regularize_matrix_svd(M, hermitean: bool = False, tol: float = None):
   """
   Regularization of a matrix wither with svd or evd depending
   on whether the matrix is symmetric or not.

   Description
   -----------
   When dealing with numerical precision issues in matrices (e.g. symmetric 
   matrices with eigenvalues spanning a very large range) regularization turns
   out to be essential. If the matrix is symmetric, the regularization is applied
   to the eigenvalues; if the matrix is not symmetric, the regularization is
   applied to the singular values. The tolerance, which defines the smallest
   distinguishable difference, is eps * max(s) where eps is the machine epsilon
   (~2.2e-16 for float64) and max(s) is the highest eigenvalue or the highest
   singular value.

   Parameters
   ----------
   M: np.ndarray
    The matrix that needs to be regularized. The matrix must be squared.
   tol: float
    The tolerance that defines the smallest distinguishable value. Default is None,
    and the tolerance is defined as eps * max(s).

   Returns
   -------
   If the matrix is symmetric, it returns the regularized matrix and a tuple
   containing the regularized eigenvalues in first position and the respective
   eigenvectors in second position. If the matrix is not symmetric, it returns
   the regularized matrix, and a tuple (U, S_reg, Vh).
   """
   U, S, Vh = np.linalg.svd(M, full_matrices=False, hermitian=hermitean)
   if tol is None:
     tol = np.amax(S, initial=0.) * np.finfo(M.dtype).eps
   reg_S = np.where(S > tol, S, 0.0)
   M_reg = np.dot(U * reg_S, Vh)
      
   return M_reg, (reg_S, Vh, U, tol)

# %% [markdown]
# # $M = (FK)^T C_Y^{-1} (FK) = RDR^T$
# Here I compute the matrix $M$ as defined above. Then I check that the SVD gives the same result as the eigen decomposition

# %%
# Compute M and make a copy
M = FK.T @ Cinv.to_numpy() @ FK

# Check that M is symmetric
assert(np.allclose(M, M.T))

# Plot M
plot_matrix(M, x_ticklocks=np.arange(0, M.shape[1], XGRID.size), x_labels=evol_basis_tex[lumi_mapping], size=(10,10), fontsize=15)

# %% [markdown]
# Here we compute the SVD of $M$ and solve the eigensystem associated with it. We find that the eigenvalues and the singular values are the same up to the threshold of numerical precision. This threshold is the machine precision for double float ($\varepsilon \sim 2.2 \times 10^{-16}$) multiplied be the largest singular value. Effectively, this defines the _relative_ tolerance.

# %%
# Compute SVD
U_M, S_M, Vh_M = np.linalg.svd(M, full_matrices=True, hermitian=True)
V_M = Vh_M.T
print(f"Max. singular value : {S_M[0]:.2e}")

# Compute the eigensystem of the regularized matrix
eigvals_M, eigvecs_M = np.linalg.eigh(M)
eigvals_M = eigvals_M[::-1]
eigvecs_M = eigvecs_M[:, ::-1]

# Define tolerance for comparison
rtol = np.amax(S_M, initial=0.) * np.finfo(M.dtype).eps

# Plot singular- and eigen-values
plt.figure(figsize=(13,9))
plt.plot(S_M, label="SV's")
plt.plot(np.abs(eigvals_M), label="abs(Eiglval's)")
plt.plot(np.linspace(0,450,100), [rtol for _ in range(100)], label=r'$\varepsilon_{rel}$' +  f'~{rtol:.2e}')
#plt.xscale('log')
plt.yscale('log')
plt.ylim([1.e-20,1.e8])
plt.legend(fontsize=20)
# Out:
# Max. singular value : 5.64e+06

# %% [markdown]
# The plot above shows that the two systems are exactly the same up to the numerical precision. Below this threshold, any value should be interpreted as numerical noise and hence must be set to zero. This form of regularization is performed in the following cell.

# %%
# Regularize the matrix
M_reg, (S_M_reg, Vh_M, U_M, tol) = regularize_matrix_svd(M, tol=rtol, hermitean=True)

# Regularize the eigenvalues
eigvals_M = [val if val > rtol else 0.0 for val in eigvals_M]

# Find the index of the first null value
arg_first_zero = np.argwhere(eigvals_M < rtol)[0][0]

# Print info
print(f"First non-zero argument : {arg_first_zero}")
# Out:
# First non-zero argument : 320

# %% [markdown]
# Note that the eigensystem and the SVD match also in terms of rotation matrix. In fact, we see that $V$ and $U$ from SVD are exactly the same up to the numerical threshold, as shown below:

# %%
for i in range(arg_first_zero):
  if not np.allclose(Vh_M.T[:,i], U_M[:,i]):
    print(f"Column {i} is not the same.")
    break

# %% [markdown]
# If we go beyond this numerical tolerance, the singular vectors and the eigenvectors start to diverge:

# %%
for i in range(arg_first_zero, S_M_reg.size):
  if not np.allclose(Vh_M.T[:,i], U_M[:,i]):
    print(f"Vector {i} is not the same.")
    break
# Out:
# Vector 320 is not the same.

# %% [markdown]
# With hindsight, this result is expected. The kernel space is not fixed and there are many directions that are equivalent. This effect is made more severe if the kernel is large.

# %% [markdown]
# ## Projection in the orthogonal space
# The vectors of $U$ associated to the non-zero singular values span the space orthogonal to Ker$(M)$. In this space, $M$ is diagonal, with entries equal to the (non-zero) singular values. The cell below shows how to obtain this subspace:

# %%
M_orth = np.diag(S_M_reg[:arg_first_zero])
print(f"Original dimension of the singular space : {S_M_reg.size}")
print(f"Dimension of the orthogonal subspace : {M_orth.shape[0]}")
# Out:
# Original dimension of the singular space : 450
# Dimension of the orthogonal subspace : 320

# %% [markdown]
# However, the matrix remains ill-conditioned even after the noise is removed:

# %%
M_rec_orth = U_M[:, :arg_first_zero].T @ M @ U_M[:, :arg_first_zero]
print(f"Condition number of M in the diagonal basis: {M_orth.diagonal()[0]/M_orth.diagonal()[-1]}")
print(f"Condition number of M in the original basis: {np.linalg.cond(M_rec_orth)}")
# Out:
# Condition number of M in the diagonal basis: 4316029648742186.5
# Condition number of M in the original basis: 6643938342819724.0

# %% [markdown]
# In order to obtain a good condition number, we need to cut more singular values. The list below displays how the condition number changes with the size of the subspace:

# %%
for j in range(arg_first_zero):
  M_orth = np.diag(S_M_reg[:arg_first_zero - j])
  print(f"Condition number of M in the diagonal basis with j = {j}: {M_orth.diagonal()[0]/M_orth.diagonal()[-1]}")
# Out:
# Condition number of M in the diagonal basis with j = 0: 4316029648742186.5
# Condition number of M in the diagonal basis with j = 1: 3377067314467445.5
# Condition number of M in the diagonal basis with j = 2: 3306059666082117.0
# Condition number of M in the diagonal basis with j = 3: 1821377013854289.8
# Condition number of M in the diagonal basis with j = 4: 1358055177885222.0
# Condition number of M in the diagonal basis with j = 5: 1317090489196737.8
# Condition number of M in the diagonal basis with j = 6: 644614496529880.2
# Condition number of M in the diagonal basis with j = 7: 329337935603224.9
# Condition number of M in the diagonal basis with j = 8: 241213393414731.25
# Condition number of M in the diagonal basis with j = 9: 236133833378064.66
# Condition number of M in the diagonal basis with j = 10: 107719020699695.78
# Condition number of M in the diagonal basis with j = 11: 84241017449953.45
# Condition number of M in the diagonal basis with j = 12: 70464490776912.89
# Condition number of M in the diagonal basis with j = 13: 37468391237784.41
# Condition number of M in the diagonal basis with j = 14: 31902220212485.71
# Condition number of M in the diagonal basis with j = 15: 28962791029724.66
# Condition number of M in the diagonal basis with j = 16: 22194528652304.434
# Condition number of M in the diagonal basis with j = 17: 14349951130940.482
# Condition number of M in the diagonal basis with j = 18: 13157582856299.822
# Condition number of M in the diagonal basis with j = 19: 10790679627892.973
# Condition number of M in the diagonal basis with j = 20: 8116653017667.1455
# Condition number of M in the diagonal basis with j = 21: 6018248640293.629
# Condition number of M in the diagonal basis with j = 22: 5178630692039.15
# Condition number of M in the diagonal basis with j = 23: 4877843794584.576
# Condition number of M in the diagonal basis with j = 24: 3302238434595.489
# Condition number of M in the diagonal basis with j = 25: 2744856548150.1353
# Condition number of M in the diagonal basis with j = 26: 2369227877042.112
# Condition number of M in the diagonal basis with j = 27: 2076935166799.9546
# Condition number of M in the diagonal basis with j = 28: 1710675677375.3962
# Condition number of M in the diagonal basis with j = 29: 1451123060816.8586
# Condition number of M in the diagonal basis with j = 30: 1142706632417.8704
# Condition number of M in the diagonal basis with j = 31: 909574488305.3606
# Condition number of M in the diagonal basis with j = 32: 692846213002.9413
# Condition number of M in the diagonal basis with j = 33: 655369361215.7709
# Condition number of M in the diagonal basis with j = 34: 619037435045.637
# Condition number of M in the diagonal basis with j = 35: 578774671135.4529
# Condition number of M in the diagonal basis with j = 36: 399209665117.5287
# Condition number of M in the diagonal basis with j = 37: 349354608176.9337
# Condition number of M in the diagonal basis with j = 38: 255555633024.87225
# Condition number of M in the diagonal basis with j = 39: 172781938991.43936
# Condition number of M in the diagonal basis with j = 40: 161864874100.74557
# Condition number of M in the diagonal basis with j = 41: 150472489408.1855
# Condition number of M in the diagonal basis with j = 42: 137311894161.59999
# Condition number of M in the diagonal basis with j = 43: 104074946612.38597
# Condition number of M in the diagonal basis with j = 44: 87643851935.71715
# Condition number of M in the diagonal basis with j = 45: 79710193712.85046
# Condition number of M in the diagonal basis with j = 46: 71744426417.15741
# Condition number of M in the diagonal basis with j = 47: 65025371832.33079
# Condition number of M in the diagonal basis with j = 48: 58581146678.681404
# Condition number of M in the diagonal basis with j = 49: 47467291343.93534
# Condition number of M in the diagonal basis with j = 50: 30039497144.239185
# Condition number of M in the diagonal basis with j = 51: 27301772185.98294
# Condition number of M in the diagonal basis with j = 52: 25455468318.81166
# Condition number of M in the diagonal basis with j = 53: 23128030308.991726
# Condition number of M in the diagonal basis with j = 54: 20437171264.548794
# Condition number of M in the diagonal basis with j = 55: 11504317787.48784
# Condition number of M in the diagonal basis with j = 56: 10334413601.874023
# Condition number of M in the diagonal basis with j = 57: 10211363718.63686
# Condition number of M in the diagonal basis with j = 58: 9262519271.125767
# Condition number of M in the diagonal basis with j = 59: 7031590885.907899
# Condition number of M in the diagonal basis with j = 60: 6034363834.334988
# Condition number of M in the diagonal basis with j = 61: 4689370642.961734
# Condition number of M in the diagonal basis with j = 62: 4158376061.8024807
# Condition number of M in the diagonal basis with j = 63: 3328275720.165275
# Condition number of M in the diagonal basis with j = 64: 2791376190.1421795
# Condition number of M in the diagonal basis with j = 65: 2651161748.2809772
# Condition number of M in the diagonal basis with j = 66: 2269201557.8697567
# Condition number of M in the diagonal basis with j = 67: 1569865763.9785047
# Condition number of M in the diagonal basis with j = 68: 1322832265.7565923
# Condition number of M in the diagonal basis with j = 69: 1179737742.0543082
# Condition number of M in the diagonal basis with j = 70: 753673288.4692419
# Condition number of M in the diagonal basis with j = 71: 714229535.8765686
# Condition number of M in the diagonal basis with j = 72: 695004541.8164955
# Condition number of M in the diagonal basis with j = 73: 644066308.2877549
# Condition number of M in the diagonal basis with j = 74: 579824589.7136382
# Condition number of M in the diagonal basis with j = 75: 500046134.6964359
# Condition number of M in the diagonal basis with j = 76: 466603667.3470792
# Condition number of M in the diagonal basis with j = 77: 457636282.9585055
# Condition number of M in the diagonal basis with j = 78: 359263864.2561999
# Condition number of M in the diagonal basis with j = 79: 336637512.3755514
# Condition number of M in the diagonal basis with j = 80: 221315380.65880552
# Condition number of M in the diagonal basis with j = 81: 203925413.83829162
# Condition number of M in the diagonal basis with j = 82: 188099172.0248745
# Condition number of M in the diagonal basis with j = 83: 181284272.9886422
# Condition number of M in the diagonal basis with j = 84: 165915825.38776731
# Condition number of M in the diagonal basis with j = 85: 130822846.79854706
# Condition number of M in the diagonal basis with j = 86: 120207864.51274146
# Condition number of M in the diagonal basis with j = 87: 118891184.7019177
# Condition number of M in the diagonal basis with j = 88: 107559886.54125534
# Condition number of M in the diagonal basis with j = 89: 103757158.33861245
# Condition number of M in the diagonal basis with j = 90: 96261689.67157157
# Condition number of M in the diagonal basis with j = 91: 76994014.96883163
# Condition number of M in the diagonal basis with j = 92: 73769273.98107597
# Condition number of M in the diagonal basis with j = 93: 71114052.0365635
# Condition number of M in the diagonal basis with j = 94: 61365191.344090484
# Condition number of M in the diagonal basis with j = 95: 58342730.22644251
# Condition number of M in the diagonal basis with j = 96: 57659674.3065313
# Condition number of M in the diagonal basis with j = 97: 44923509.65571826
# Condition number of M in the diagonal basis with j = 98: 38418829.515686095
# Condition number of M in the diagonal basis with j = 99: 36542775.92434787
# Condition number of M in the diagonal basis with j = 100: 29054398.68724951
# Condition number of M in the diagonal basis with j = 101: 27176172.17927957
# Condition number of M in the diagonal basis with j = 102: 26740819.82124435
# Condition number of M in the diagonal basis with j = 103: 21980178.3264855
# Condition number of M in the diagonal basis with j = 104: 21438527.134271454
# Condition number of M in the diagonal basis with j = 105: 18867376.52259738
# Condition number of M in the diagonal basis with j = 106: 18377410.1041222
# Condition number of M in the diagonal basis with j = 107: 16572307.018720975
# Condition number of M in the diagonal basis with j = 108: 15794866.423463047
# Condition number of M in the diagonal basis with j = 109: 15282674.250511583
# Condition number of M in the diagonal basis with j = 110: 12358820.075049257
# Condition number of M in the diagonal basis with j = 111: 12048583.637278609
# Condition number of M in the diagonal basis with j = 112: 10929750.982550193
# Condition number of M in the diagonal basis with j = 113: 10478086.650759052
# Condition number of M in the diagonal basis with j = 114: 10247667.202574695
# Condition number of M in the diagonal basis with j = 115: 9455546.231943188
# Condition number of M in the diagonal basis with j = 116: 8944499.231901456
# Condition number of M in the diagonal basis with j = 117: 8741232.81305923
# Condition number of M in the diagonal basis with j = 118: 7267437.893937705
# Condition number of M in the diagonal basis with j = 119: 6627595.497087038
# Condition number of M in the diagonal basis with j = 120: 6566084.324540908
# Condition number of M in the diagonal basis with j = 121: 6008899.392935371
# Condition number of M in the diagonal basis with j = 122: 5903100.772696719
# Condition number of M in the diagonal basis with j = 123: 5505282.731198378
# Condition number of M in the diagonal basis with j = 124: 4628178.51120964
# Condition number of M in the diagonal basis with j = 125: 4505028.536226253
# Condition number of M in the diagonal basis with j = 126: 4008992.56245894
# Condition number of M in the diagonal basis with j = 127: 3808833.33730743
# Condition number of M in the diagonal basis with j = 128: 3547740.7179978737
# Condition number of M in the diagonal basis with j = 129: 3480164.0523294928
# Condition number of M in the diagonal basis with j = 130: 3192071.0587118003
# Condition number of M in the diagonal basis with j = 131: 3040160.5158151807
# Condition number of M in the diagonal basis with j = 132: 2967743.895846984
# Condition number of M in the diagonal basis with j = 133: 2819675.4824123723
# Condition number of M in the diagonal basis with j = 134: 2506338.825992974
# Condition number of M in the diagonal basis with j = 135: 2127399.3209273946
# Condition number of M in the diagonal basis with j = 136: 2087453.9320044226
# Condition number of M in the diagonal basis with j = 137: 2001208.9172978105
# Condition number of M in the diagonal basis with j = 138: 1873001.6211311761
# Condition number of M in the diagonal basis with j = 139: 1765800.6572632177
# Condition number of M in the diagonal basis with j = 140: 1749954.613228904
# Condition number of M in the diagonal basis with j = 141: 1725886.8490330584
# Condition number of M in the diagonal basis with j = 142: 1448634.8580826025
# Condition number of M in the diagonal basis with j = 143: 1401798.5455704283
# Condition number of M in the diagonal basis with j = 144: 1306310.0217149646
# Condition number of M in the diagonal basis with j = 145: 1287592.2745336476
# Condition number of M in the diagonal basis with j = 146: 1232781.7895487943
# Condition number of M in the diagonal basis with j = 147: 1121587.0955463923
# Condition number of M in the diagonal basis with j = 148: 1036252.7217896429
# Condition number of M in the diagonal basis with j = 149: 921252.6067463609
# Condition number of M in the diagonal basis with j = 150: 905043.9185628891
# Condition number of M in the diagonal basis with j = 151: 847204.046136076
# Condition number of M in the diagonal basis with j = 152: 768114.615242824
# Condition number of M in the diagonal basis with j = 153: 649077.0387502969
# Condition number of M in the diagonal basis with j = 154: 595325.5081594386
# Condition number of M in the diagonal basis with j = 155: 571552.8204132592
# Condition number of M in the diagonal basis with j = 156: 547589.9313416285
# Condition number of M in the diagonal basis with j = 157: 519307.5962630391
# Condition number of M in the diagonal basis with j = 158: 493922.4182988675
# Condition number of M in the diagonal basis with j = 159: 464934.0795019495
# Condition number of M in the diagonal basis with j = 160: 438357.5986439917
# Condition number of M in the diagonal basis with j = 161: 423566.55575569463
# Condition number of M in the diagonal basis with j = 162: 417453.6797186518
# Condition number of M in the diagonal basis with j = 163: 339520.69373795984
# Condition number of M in the diagonal basis with j = 164: 318666.87419091666
# Condition number of M in the diagonal basis with j = 165: 315240.11753276805
# Condition number of M in the diagonal basis with j = 166: 271330.6802671466
# Condition number of M in the diagonal basis with j = 167: 251039.86791276265
# Condition number of M in the diagonal basis with j = 168: 243380.53938989912
# Condition number of M in the diagonal basis with j = 169: 224549.29171820224
# Condition number of M in the diagonal basis with j = 170: 222466.6865765886
# Condition number of M in the diagonal basis with j = 171: 167903.30200838362
# Condition number of M in the diagonal basis with j = 172: 164205.31043226007
# Condition number of M in the diagonal basis with j = 173: 153980.53443050088
# Condition number of M in the diagonal basis with j = 174: 146675.36397124943
# Condition number of M in the diagonal basis with j = 175: 143699.22823454297
# Condition number of M in the diagonal basis with j = 176: 140780.15143404258
# Condition number of M in the diagonal basis with j = 177: 124019.87169923131
# Condition number of M in the diagonal basis with j = 178: 113100.60886620484
# Condition number of M in the diagonal basis with j = 179: 108316.14236538818
# Condition number of M in the diagonal basis with j = 180: 99412.23989298947
# Condition number of M in the diagonal basis with j = 181: 93225.0965271346
# Condition number of M in the diagonal basis with j = 182: 91634.01218778541
# Condition number of M in the diagonal basis with j = 183: 86485.94620563614
# Condition number of M in the diagonal basis with j = 184: 83911.23409841573
# Condition number of M in the diagonal basis with j = 185: 75982.28879462584
# Condition number of M in the diagonal basis with j = 186: 67054.46272378431
# Condition number of M in the diagonal basis with j = 187: 65870.37866564239
# Condition number of M in the diagonal basis with j = 188: 56613.68644968814
# Condition number of M in the diagonal basis with j = 189: 54555.93260777575
# Condition number of M in the diagonal basis with j = 190: 49156.708727511505
# Condition number of M in the diagonal basis with j = 191: 44388.94195142531
# Condition number of M in the diagonal basis with j = 192: 42707.387518098214
# Condition number of M in the diagonal basis with j = 193: 39757.46913388781
# Condition number of M in the diagonal basis with j = 194: 34255.641157582344
# Condition number of M in the diagonal basis with j = 195: 30882.62993908872
# Condition number of M in the diagonal basis with j = 196: 30507.94593425834
# Condition number of M in the diagonal basis with j = 197: 29462.9294701388
# Condition number of M in the diagonal basis with j = 198: 28711.529123337485
# Condition number of M in the diagonal basis with j = 199: 26945.03584849863
# Condition number of M in the diagonal basis with j = 200: 26723.6248124827
# Condition number of M in the diagonal basis with j = 201: 26006.78804076922
# Condition number of M in the diagonal basis with j = 202: 22609.068608307418
# Condition number of M in the diagonal basis with j = 203: 21895.184925522986
# Condition number of M in the diagonal basis with j = 204: 20780.57942750537
# Condition number of M in the diagonal basis with j = 205: 19978.30656445691
# Condition number of M in the diagonal basis with j = 206: 18916.75832141304
# Condition number of M in the diagonal basis with j = 207: 18206.881739576864
# Condition number of M in the diagonal basis with j = 208: 17326.576861023317
# Condition number of M in the diagonal basis with j = 209: 16257.058639256671
# Condition number of M in the diagonal basis with j = 210: 15096.910625194761
# Condition number of M in the diagonal basis with j = 211: 14471.063633670463
# Condition number of M in the diagonal basis with j = 212: 14316.307234971006
# Condition number of M in the diagonal basis with j = 213: 14086.074262304672
# Condition number of M in the diagonal basis with j = 214: 13716.423655524766
# Condition number of M in the diagonal basis with j = 215: 12539.844882465017
# Condition number of M in the diagonal basis with j = 216: 12507.77872842835
# Condition number of M in the diagonal basis with j = 217: 12117.961409025904
# Condition number of M in the diagonal basis with j = 218: 11725.997151512356
# Condition number of M in the diagonal basis with j = 219: 10575.469967576764
# Condition number of M in the diagonal basis with j = 220: 9893.438247901262
# Condition number of M in the diagonal basis with j = 221: 9726.452127775183
# Condition number of M in the diagonal basis with j = 222: 9352.846459934302
# Condition number of M in the diagonal basis with j = 223: 8853.229422829521
# Condition number of M in the diagonal basis with j = 224: 7408.804320094608
# Condition number of M in the diagonal basis with j = 225: 7268.176837732143
# Condition number of M in the diagonal basis with j = 226: 7001.737392525663
# Condition number of M in the diagonal basis with j = 227: 6823.343787140472
# Condition number of M in the diagonal basis with j = 228: 6753.4409569977
# Condition number of M in the diagonal basis with j = 229: 6124.137388668279
# Condition number of M in the diagonal basis with j = 230: 6089.463538857376
# Condition number of M in the diagonal basis with j = 231: 6036.827427748393
# Condition number of M in the diagonal basis with j = 232: 5989.783675006188
# Condition number of M in the diagonal basis with j = 233: 5410.806075430342
# Condition number of M in the diagonal basis with j = 234: 5271.197080753388
# Condition number of M in the diagonal basis with j = 235: 5114.4524759097085
# Condition number of M in the diagonal basis with j = 236: 4954.582530594902
# Condition number of M in the diagonal basis with j = 237: 4849.733003990468
# Condition number of M in the diagonal basis with j = 238: 4361.226193537104
# Condition number of M in the diagonal basis with j = 239: 4061.0625837245493
# Condition number of M in the diagonal basis with j = 240: 3981.338717869076
# Condition number of M in the diagonal basis with j = 241: 3886.5701272903507
# Condition number of M in the diagonal basis with j = 242: 3854.4870683968456
# Condition number of M in the diagonal basis with j = 243: 3643.275308051037
# Condition number of M in the diagonal basis with j = 244: 3503.163514523447
# Condition number of M in the diagonal basis with j = 245: 3174.8057864198513
# Condition number of M in the diagonal basis with j = 246: 3079.584055214998
# Condition number of M in the diagonal basis with j = 247: 2986.4630177922872
# Condition number of M in the diagonal basis with j = 248: 2785.8214667952016
# Condition number of M in the diagonal basis with j = 249: 2573.328016539499
# Condition number of M in the diagonal basis with j = 250: 2391.593320114191
# Condition number of M in the diagonal basis with j = 251: 2339.598500206063
# Condition number of M in the diagonal basis with j = 252: 2177.6073254593916
# Condition number of M in the diagonal basis with j = 253: 2110.2485343672656
# Condition number of M in the diagonal basis with j = 254: 2066.1103116016125
# Condition number of M in the diagonal basis with j = 255: 1974.0884391149064
# Condition number of M in the diagonal basis with j = 256: 1898.8996130338287
# Condition number of M in the diagonal basis with j = 257: 1862.2698920384528
# Condition number of M in the diagonal basis with j = 258: 1708.1816551309157
# Condition number of M in the diagonal basis with j = 259: 1651.2143916016523
# Condition number of M in the diagonal basis with j = 260: 1574.937470281941
# Condition number of M in the diagonal basis with j = 261: 1444.0912441683488
# Condition number of M in the diagonal basis with j = 262: 1380.2798065172592
# Condition number of M in the diagonal basis with j = 263: 1287.035465563005
# Condition number of M in the diagonal basis with j = 264: 1268.962165995026
# Condition number of M in the diagonal basis with j = 265: 1174.5750752014949
# Condition number of M in the diagonal basis with j = 266: 1109.9879153383274
# Condition number of M in the diagonal basis with j = 267: 1082.8443352825334
# Condition number of M in the diagonal basis with j = 268: 1016.6947074548134
# Condition number of M in the diagonal basis with j = 269: 967.7372087096851
# Condition number of M in the diagonal basis with j = 270: 923.5827832051439
# Condition number of M in the diagonal basis with j = 271: 894.0912667767689
# Condition number of M in the diagonal basis with j = 272: 879.9292844706254
# Condition number of M in the diagonal basis with j = 273: 836.1852974935819
# Condition number of M in the diagonal basis with j = 274: 772.8599002802151
# Condition number of M in the diagonal basis with j = 275: 720.9119232739891
# Condition number of M in the diagonal basis with j = 276: 679.1053923309571
# Condition number of M in the diagonal basis with j = 277: 662.7012372562506
# Condition number of M in the diagonal basis with j = 278: 604.3337748220905
# Condition number of M in the diagonal basis with j = 279: 588.1173976886802
# Condition number of M in the diagonal basis with j = 280: 560.5558476699133
# Condition number of M in the diagonal basis with j = 281: 547.242488661557
# Condition number of M in the diagonal basis with j = 282: 522.0374942221837
# Condition number of M in the diagonal basis with j = 283: 505.91552163031486
# Condition number of M in the diagonal basis with j = 284: 498.7749943624242
# Condition number of M in the diagonal basis with j = 285: 454.7845334483668
# Condition number of M in the diagonal basis with j = 286: 451.8241094257787
# Condition number of M in the diagonal basis with j = 287: 434.29783346038
# Condition number of M in the diagonal basis with j = 288: 385.9368966075238
# Condition number of M in the diagonal basis with j = 289: 373.40479373445106
# Condition number of M in the diagonal basis with j = 290: 366.2245538229717
# Condition number of M in the diagonal basis with j = 291: 354.8829241739935
# Condition number of M in the diagonal basis with j = 292: 353.60653184879374
# Condition number of M in the diagonal basis with j = 293: 327.69049541525476
# Condition number of M in the diagonal basis with j = 294: 314.4608040027427
# Condition number of M in the diagonal basis with j = 295: 276.77126391272344
# Condition number of M in the diagonal basis with j = 296: 267.3958162143093
# Condition number of M in the diagonal basis with j = 297: 257.6912499175964
# Condition number of M in the diagonal basis with j = 298: 252.63185413802128
# Condition number of M in the diagonal basis with j = 299: 207.66080700091248
# Condition number of M in the diagonal basis with j = 300: 199.77340696988784
# Condition number of M in the diagonal basis with j = 301: 186.20560787090145
# Condition number of M in the diagonal basis with j = 302: 182.9712558659777
# Condition number of M in the diagonal basis with j = 303: 140.61511244975952
# Condition number of M in the diagonal basis with j = 304: 121.71615250949233
# Condition number of M in the diagonal basis with j = 305: 98.93882394872415
# Condition number of M in the diagonal basis with j = 306: 89.79018032113635
# Condition number of M in the diagonal basis with j = 307: 87.76167604054054
# Condition number of M in the diagonal basis with j = 308: 79.43393942867924
# Condition number of M in the diagonal basis with j = 309: 66.18712145678724
# Condition number of M in the diagonal basis with j = 310: 56.32225263820736
# Condition number of M in the diagonal basis with j = 311: 48.86900513123001
# Condition number of M in the diagonal basis with j = 312: 40.25500711174193
# Condition number of M in the diagonal basis with j = 313: 35.243511466792086
# Condition number of M in the diagonal basis with j = 314: 30.13265301930738
# Condition number of M in the diagonal basis with j = 315: 20.997030926089426
# Condition number of M in the diagonal basis with j = 316: 10.048234101717025
# Condition number of M in the diagonal basis with j = 317: 6.97677455179275
# Condition number of M in the diagonal basis with j = 318: 2.614465003515588
# Condition number of M in the diagonal basis with j = 319: 1.0

# %% [markdown]
# Here we cann see how this cut affects the inverse problem

# %%
cut_size = [100, 150, 250, 300]
reduced_space_size = [arg_first_zero - j for j in cut_size]
M_orth = [np.diag(S_M_reg[:reduced_space]) for reduced_space in reduced_space_size]
M_orth_inv = [np.linalg.inv(M_orth_i) for M_orth_i in M_orth]
FK_orth = [FK @ U_M[:, :reduced_space] for reduced_space in reduced_space_size]

print(f"Studying the following reduced dimensions:")
for i in range(len(cut_size)):
  print(f"Reduced dimension: {reduced_space_size[i]}")

# Test that the explicit projection is the diagonal matrix M_orth defined above
for i in range(len(cut_size)):
  M_test = U_M[:, :reduced_space_size[i]].T @ M @ U_M[:, :reduced_space_size[i]]
  assert(np.allclose(M_test, M_orth[i]))
# Out:
# Studying the following reduced dimensions:
# Reduced dimension: 220
# Reduced dimension: 170
# Reduced dimension: 70
# Reduced dimension: 20

# %%
fig, axs = plt.subplots(3, 3, figsize=(15, 15))

f_inf_list = []
eps_inf_list = []
L_inf_list = []

for i in range(len(cut_size)):
  f_inf = M_orth_inv[i] @ FK_orth[i].T @ Cinv.to_numpy(dtype='float64') @ Y.to_numpy(dtype='float64')[:,0]
  eps_inf = Y.to_numpy(dtype='float64')[:,0] - FK_orth[i] @ f_inf
  L_inf = 0.5 * Y.to_numpy(dtype='float64')[:,0].T @ Cinv.to_numpy(dtype='float64') @ eps_inf / Y.size
  f_inf_list.append(f_inf)
  eps_inf_list.append(eps_inf)
  L_inf_list.append(L_inf)


  f = U_M[:, :reduced_space_size[i]] @ f_inf
  f = f.reshape((9, f.size // 9))


  for j, ax in enumerate(axs.flatten()):
    flav_label = evol_basis[lumi_mapping[j]]
    ax.plot(XGRID, f[j], label=f"dim={reduced_space_size[i]}")
    ax.set_title(f"{flav_label}")
    ax.set_xscale('log')
    ax.set_xlim([1.e-5, 1.])
    ax.set_ylim([-3., 3.])
    ax.legend()

# %% [markdown]
# # $\tilde{H_{\epsilon}} = D_Y^{1/2} R_Y^T (FK) \Theta (FK)^T R_Y D_Y^{1/2}$

# %%
# Set the size of the orthogonal space
reduced_space_size = arg_first_zero - 150

# Compute Hte
ntk = U_M[:, :reduced_space_size].T @ NTK_flat @ U_M[:, :reduced_space_size]
Hte = np.sqrt(D_Y) @ R_Y.T @ FK_orth @ ntk @ FK_orth.T @ R_Y @ np.sqrt(D_Y)

# Compute matrices and vectors required later
M_orth = np.diag(S_M_reg[:reduced_space_size])
M_orth_inv = np.linalg.inv(M_orth)
FK_orth = FK @ U_M[:, :reduced_space_size]
f_inf = M_orth_inv @ FK_orth.T @ Cinv.to_numpy(dtype='float64') @ Y.to_numpy(dtype='float64')[:,0]
eps_inf = Y.to_numpy(dtype='float64')[:,0] - FK_orth @ f_inf

# Compute SVD
U_hte, S_hte, Vh_hte = np.linalg.svd(Hte, full_matrices=True, hermitian=True)

# Compute eigenvalues
eigvals_Hte, eigvecs_Hte = np.linalg.eigh(Hte)
eigvals_Hte = eigvals_Hte[::-1]
eigvecs_Hte = eigvecs_Hte[:, ::-1]

# Define tolerance
rtol = np.amax(S_hte, initial=0.) * np.finfo(Hte.dtype).eps

# Plot singular values and eigenvalues
plt.figure(figsize=(15,10))
plt.plot(S_hte, label="SV's")
plt.plot(np.abs(eigvals_Hte), label="abs(Eiglval's)")
plt.plot(np.linspace(0,eigvals_Hte.size,100), [rtol for _ in range(100)], label=r'$\varepsilon_{rel}$' +  f'~{rtol:.2e}')
plt.xscale('log')
plt.yscale('log')
plt.ylim([1.e-20,1.e8])
plt.legend(fontsize=20)

print(f"Max. singular value : {S_hte[0]:.2e}")
assert(np.allclose(Hte, Hte.T))
# Out:
# Max. singular value : 1.34e+07

# %%
# Regularize the matrix
Hte, (S_hte_reg, Vh_hte, U_hte, tol) = regularize_matrix_svd(Hte, tol=rtol, hermitean=True)

# Regularize the eigenvalues
eigvals_Hte = [val if val > rtol else 0.0 for val in eigvals_Hte]

# Reconstruct the pseudo-inverse
S_hte_reg_dag = [1/val if val != 0.0 else 0.0 for val in S_hte_reg]
Hte_my_pinv = Vh_hte.T @ np.diag(S_hte_reg_dag) @ U_hte.T

# %% [markdown]
# We also compute the following quantity, which will be useful in the description of the evolution
# $$
# \begin{align}
# & \tilde{\varepsilon}_{\infty} = D_{Y}^{1/2} \, R_Y^T \varepsilon_{\infty} \hspace{5mm} \textrm{where} \hspace{5mm} C_Y^{-1} = R_Y D_Y R_Y^T \\
# \end{align}
# $$

# %%
eps_inf_tilde = np.sqrt(D_Y) @ R_Y.T @ eps_inf

# %% [markdown]
# We now check eq.(67) of the paper, that is
# $$
# \tilde{H}_{\varepsilon} \, \tilde{\varepsilon}_{\infty} = 0
# $$

# %%
res = Hte @ eps_inf_tilde
print(f"max value of res : {np.amax(res)}")
print(f"min value of res : {np.amin(res)}")
# Out:
# max value of res : 2.5543849915266037e-06
# min value of res : -4.030065611004829e-06
