# %%
import numpy as np
import pandas as pd
import pickle

# %%
# Deserialize fk tables
with open('fk_dict.pkl', 'rb') as f:
  fk_tables_dict = pickle.load(f)

# Deserialize central data
with open('central_data_dict.pkl', 'rb') as f:
  central_data_dict = pickle.load(f)

# Deserialize covmat
C = pd.read_pickle('covmat.pkl')

# %%
# example for fk tables
fk_tables_dict['BCDMS_NC_NOTFIXED_D_EM-F2']
# Out:
# <tf.Tensor: shape=(248, 50, 9), dtype=float32, numpy=
# array([[[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         ...,
#         [ 9.31731425e-04,  1.39287440e-03,  1.57079543e-19, ...,
#           4.67454708e-21,  1.08157605e-04, -1.26715226e-04],
#         [ 1.29282847e-03,  1.96197024e-03,  1.92895042e-19, ...,
#           4.99430070e-20,  1.39606476e-04, -1.79782524e-04],
#         [ 3.55641911e-04,  5.24121395e-04,  4.57396758e-20, ...,
#          -4.20202829e-22,  4.48585888e-05, -5.19236892e-05]],
#
#        [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
# ...

# %%
# example for Y
central_data_dict['BCDMS_NC_NOTFIXED_D_EM-F2']
# Out:
# array([0.36575, 0.36092, 0.3536 , 0.35702, 0.34834, 0.33013, 0.34016,
#        0.33475, 0.33123, 0.3378 , 0.31451, 0.31298, 0.30061, 0.30601,
#        0.30947, 0.29547, 0.29306, 0.27761, 0.28678, 0.27833, 0.27099,
#        0.27198, 0.26953, 0.26596, 0.25886, 0.25756, 0.25851, 0.24795,
#        0.23909, 0.23758, 0.23279, 0.2345 , 0.23381, 0.22833, 0.21961,
#        0.21705, 0.1829 , 0.18873, 0.17893, 0.17382, 0.18531, 0.17836,
#        0.17729, 0.17661, 0.17234, 0.16928, 0.16545, 0.16205, 0.12068,
#        0.11853, 0.12108, 0.11283, 0.11759, 0.10949, 0.10915, 0.10904,
#        0.10842, 0.10518, 0.09777, 0.10295, 0.09701, 0.09586, 0.05714,
#        0.06287, 0.0592 , 0.05595, 0.05904, 0.05668, 0.05511, 0.05589,
#        0.05493, 0.04965, 0.05175, 0.04983, 0.04681, 0.02861, 0.0237 ,
#        0.0246 , 0.02521, 0.02659, 0.02449, 0.02296, 0.02062, 0.02491,
#        0.01926, 0.02329, 0.008  , 0.00861, 0.00876, 0.00785, 0.00775,
# ...

# %%
# extract the the uncertainties of a dataset from the full covariance matrix
C.xs(level='dataset', key='BCDMS_NC_NOTFIXED_D_EM-F2').T.xs(level='dataset', key='BCDMS_NC_NOTFIXED_D_EM-F2')
# Out:
# group             DIS NC                                                      \
# id                   0             1         2             3             4
# group  id
# DIS NC 0    1.986957e-04  1.612975e-04  0.000148  1.498133e-04  1.494703e-04
#        1    1.612975e-04  2.054500e-04  0.000153  1.553427e-04  1.538633e-04
#        2    1.484925e-04  1.531219e-04  0.000162  1.438305e-04  1.424682e-04
#        3    1.498133e-04  1.553427e-04  0.000144  1.667543e-04  1.438602e-04
#        4    1.494703e-04  1.538633e-04  0.000142  1.438602e-04  1.671852e-04
# ...                  ...           ...       ...           ...           ...
#        249  2.348319e-08  2.869618e-07  0.000002  1.287081e-06  4.770826e-07
#        250 -5.652816e-08 -5.979509e-08  0.000001  1.073367e-06  3.440389e-07
#        251 -1.474185e-07 -3.072188e-07  0.000001  8.940779e-07  2.206730e-07
#        252 -2.101223e-07 -4.368175e-07  0.000001  7.843064e-07  1.384722e-07
# ...
